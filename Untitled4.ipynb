# %%
import cv2 as cv
import numpy as np
import splitfolders
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


import PIL

import seaborn as sns
from tqdm import tqdm
from skimage.io import imread


print
('import cv2 as cv'
)
# Out:
#   File "C:\Users\NAIDA\AppData\Local\Temp\ipykernel_3180\1009102442.py", line 25
#     ('import cv2 as cv
#                       ^
# SyntaxError: EOL while scanning string literal

# %%
train = 0.7
val = 0.2
test = 0.1
epochs = 20,
seed = 115
batch_size=32
img_width = 224
img_height = 224 
datagen = ImageDataGenerator(
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    shear_range = 0.2,
    zoom_range = 0.2
)

#datagen = ImageDataGenerator()

# %%
#images = []
#labels = []
#imagesize = 256

#Storing all the image directories in the 'images' array and corresponding them to either 1 for TB images or 0 for normal images.
#for x in os.listdir(normal_donner):
 #   imagedir = os.path.join(normal_donner, x)
 #   image = cv.imread(imagedir, cv.IMREAD_GRAYSCALE)
 #   image = cv.resize(image, (imagesize, imagesize))
 #   images.append(image)
 #   labels.append(0)
    
#for y in os.listdir(tuberculose_donner):
 #   imagedir = os.path.join(tuberculose_donner, y)
 #   image = cv.imread(imagedir, cv.IMREAD_GRAYSCALE)
 #   image = cv.resize(image, (imagesize, imagesize))
 #   images.append(image)
 #   labels.append(1)

# %%
print('# Definir repertoire données')
print('donner = Path("MemoireIngenieur/TB_Chest_Radiography_Database/")')
print('')
print('# Definir sous repertoire données')
print('normal_donner = donner / "Normal"')
print('tuberculose_donner = donner / "Tuberculosis"')
print('')
print('# Creer le reprtoire des images de (train,val,test)')
print('splitfolders.ratio(donner, output = "MemoireIngenieur/TB_Images", seed = seed, ratio = (train, val, test), group_prefix = None)')
print('')
print('# Definir repertoire données(train,val,test)')
print('train_donner = "MemoireIngenieur/TB_Images/train"')
print('val_donner = "MemoireIngenieur/TB_Images/val"')
print('test_donner = "MemoireIngenieur/TB_Images/test"')
# Out:
# # Definir repertoire données
# donner = Path("MemoireIngenieur/TB_Chest_Radiography_Database/")
#
# # Definir sous repertoire données
# normal_donner = donner / "Normal"
# tuberculose_donner = donner / "Tuberculosis"
#
# # Creer le reprtoire des images de (train,val,test)
# splitfolders.ratio(donner, output = "MemoireIngenieur/TB_Images", seed = seed, ratio = (train, val, test), group_prefix = None)
#
# # Definir repertoire données(train,val,test)
# train_donner = "MemoireIngenieur/TB_Images/train"
# val_donner = "MemoireIngenieur/TB_Images/val"
# test_donner = "MemoireIngenieur/TB_Images/test"

# %%
img_normal = list(normal_donner.glob('*.png'))
img_tuberculose = list( tuberculose_donner.glob('*.png'))

# %%
image_index = 0

# Print the Image Dimensions
img = PIL.Image.open(img_normal[image_index])

print("Image Size: ", img.size)

# Look at the Image
img
# Out:
# Image Size:  (512, 512)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# Print the Image Dimensions
img1 = PIL.Image.open(img_tuberculose[image_index])

print("Image Size: ", img1.size)

# Look at the Image
img1
# Out:
# Image Size:  (512, 512)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# 
nbr_normal = len(list(normal_donner.glob('*.png')))
nbr_tuberculose = len(list( tuberculose_donner.glob('*.png')))

print("Nombre image norrmal : ", nbr_normal)
print("Nombre image tuberculose : ", nbr_tuberculose)
print("Total image : ", nbr_normal + nbr_tuberculose)

# Del directorio de imagenes para entrenamiento se hace un cambio en su tamaño para que queden de 224x224 [px], tomando lotes de 15 por ciclo
Train_generator = datagen.flow_from_directory(
    train_donner,
    target_size=(img_height, img_width),
    batch_size = batch_size
)

# Del directorio de imagenes para validacion se hace un cambio en su tamaño para que queden de 224x224 [px], tomando lotes de 15 por ciclo
val_generator = datagen.flow_from_directory(
    val_donner,
    target_size=(img_height, img_width),
    batch_size = batch_size
)

# Del directorio de imagenes para test se hace un cambio en su tamaño para que queden de 224x224 [px], tomando lotes de 15 por ciclo
Test_generator = datagen.flow_from_directory(
    test_donner,
    target_size=(img_height, img_width),
    batch_size = batch_size
)

#print("Things in the train folder: ", Train_generator.class_names)
#print("Things in the val folder: ", val_generator.class_names)
#print("Things in the test folder: ", Test_generator.class_names)
# Out:
# Nombre image norrmal :  3500
# Nombre image tuberculose :  700
# Total image :  4200
# Found 2939 images belonging to 2 classes.
# Found 840 images belonging to 2 classes.
# Found 421 images belonging to 2 classes.

# %%
# la forma de entrada predefinida sera de 224x224 y contendra 3 canales
######input_shape = (img_width, img_height, 3)

# modelo DenseNet-169 pre-entrenado en ImageNet
# weights='imagenet => los pesos pre-entrenados en el conjunto de datos ImageNet
# include_top=False => excluir las capas completamente conectadas (top layers)
#######dense_net = tf.keras.applications.DenseNet169(weights = 'imagenet', input_shape = input_shape,include_top = False)

# Se congelan todas las capas del modelo DenseNet-169 para que no se entrenen nuevamente
#####for layer in dense_net.layers:
     ######layer.trainable = False

# %%
#from tensorflow import keras
normalizer = tf.keras.layers.Rescaling(scale=1/255)

# %%
#from tensorflow import keras

model = Sequential([
    keras.Input(shape=(224,224,3)),
    normalizer,
    #Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    #keras.layers.Conv2D(128, (3, 3), activation='relu'),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.4),
    
    Dense(64, activation='relu'),
    Dropout(0.4),
    
    Dense(2, activation='softmax') # Input layer classifier layer
])

model.compile(optimizer ='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_10 (Rescaling)    (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# ...

# %%
# Entrainnement du modele
#mc = keras.callbacks.ModelCheckpoint ('mejor_modelo.h5', monitor='val_loss', save_best_only=True)
#mc = keras.callbacks.ModelCheckpoint ('mejor_modelo.h5', monitor='val_loss', save_best_only=True)
print('early_stopping = tf.keras.callbacks.EarlyStopping')
print('      (')
print('          monitor="val_loss",') 
print('          patience=10,verbose = 1')
print('      )')


print('history = model.fit')
print('       (')
print('          Train_generator, ')
print('          epochs=1, ')
print('          validation_data=val_generator,')
print('          callbacks=[early_stopping]')
print('       )')


#history_model1 = model1.fit(train_ds, epochs=10, validation_data=val_ds, workers=1, verbose=1)
# Out:
# early_stopping = tf.keras.callbacks.EarlyStopping
#       (
#           monitor="val_loss",
#           patience=10,verbose = 1
#       )
# history = model.fit
#        (
#           Train_generator,
#           epochs=1,
#           validation_data=val_generator,
#           callbacks=[early_stopping]
#        )

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
plt.figure(figsize=(12, 4))

# Plotting training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plotting training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
img_path = 'MemoireIngenieur/TB_Chest_Radiography_Database/Normal/Normal-27.png'
fig, axs = plt.subplots(1,2, figsize=(10,10))

for idx, ax in enumerate(axs.ravel()):
#     random_idx = random.randint(0,len(data)-1)
    img = cv.imread(img_path[idx], cv.IMREAD_GRAYSCALE)
    
    ax.imshow(img, cmap= 'gray')
    ax.set_title(img_path[idx].split('/')[-1].split('.')[0])
    ax.axis('off')
    
plt.show()
#img_path = 'MemoireIngenieur/TB_Chest_Radiography_Database/Normal/Tuberculosis-28.PNG'
#img = image.load_img(img_path, target_size=(150, 150))
#img_array = image.img_to_array(img)
#img_array = np.expand_dims(img_array, axis=0) / 255.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11784\1529149817.py in <module>
#       6     img = cv.imread(img_path[idx], cv.IMREAD_GRAYSCALE)
#       7
# ----> 8     ax.imshow(img, cmap= 'gray')
#       9     ax.set_title(img_path[idx].split('/')[-1].split('.')[0])
#      10     ax.axis('off')
#
# d:\projetmemeoire\detecttb\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# d:\projetmemeoire\detecttb\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
plot_training_history(history)

# %%
#Evaluating the data w/ multiple types of metrics
print('TESTING DATA:')
cnn.evaluate(imagetest, labeltest, batch_size=32, verbose=2)

print('ADVANCED TESTING METRICS:')
from sklearn.metrics import classification_report, confusion_matrix
predictions = cnn.predict(imagetest, batch_size=32)
predicted_labels = (predictions > 0.5).astype('int32')
print(classification_report(labeltest, predicted_labels))
print(confusion_matrix(labeltest, predicted_labels))

# %%
print('loss et accuracy du model:', model.evaluate(Test_generator))

# %%
scores = model.evaluate(Test_generator)
best_model = keras.models.load_model("mejor_modelo.h5")
best_model.evaluate(Test_generator)

# %%
from IPython.display import display
import Files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15252\3894843709.py in <module>
#       1 from IPython.display import display
# ----> 2 import Files
#
# ModuleNotFoundError: No module named 'Files'
